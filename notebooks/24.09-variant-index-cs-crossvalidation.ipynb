# %%
from pyspark.sql import functions as F

from gentropy.common.session import Session
from gentropy.dataset.study_locus import StudyLocus, StudyLocusQualityCheck
from gentropy.dataset.variant_index import VariantIndex
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="bb3e448c-7fcc-4847-8d08-a5e5a39c9895">Loading BokehJS ...</span>
#     </div>

# %%
flag = StudyLocusQualityCheck.INVALID_VARIANT_IDENTIFIER
variant_index = "gs://genetics_etl_python_playground/releases/24.08+szsz/variant_index"
valid_cs = "gs://genetics_etl_python_playground/releases/24.09/credible_set"

# %%
session = Session()
# Out:
# 24/09/12 15:20:43 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
vi = VariantIndex.from_parquet(path=variant_index, session=session)
cs = StudyLocus.from_parquet(path=valid_cs, session=session)
# Out:
# 24/09/12 15:21:00 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 1 for reason Executor for container container_1726154002723_0001_01_000001 exited because of a YARN event (e.g., preemption) and not because of an error in the running job.

# %%
vcs = cs.validate_variant_identifiers(vi).df.filter(F.array_contains("qualityControls", flag.name)).cache()
vcs.count()
# Out:
# 0
